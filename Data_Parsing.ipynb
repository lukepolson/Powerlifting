# %% [markdown]
# <h1 id="tocheading">Table of Contents and Notebook Setup</h1>
# <div id="toc"></div>

# %%
# %%javascript
# $.getScript('https://kmahelona.github.io/ipython_notebook_goodies/ipython_notebook_toc.js')

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
from scipy import misc
from scipy.optimize import curve_fit
import seaborn as sns
from IPython.display import display, HTML

# %% [markdown]
# # Read in the Data

# %%
df = pd.read_csv('https://github.com/sstangl/openpowerlifting-static/raw/gh-pages/openpowerlifting.csv.bz2')
display(df)
# Out:
# C:\Users\lukep\AppData\Local\Continuum\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                           Name Sex Event   Equipment   Age      Division  \
# 0             Angie Belk Terry   F   SBD       Wraps  47.0     Mst 45-49
# 1                  Dawn Bogart   F   SBD  Single-ply  42.0     Mst 40-44
# 2                  Dawn Bogart   F   SBD  Single-ply  42.0   Open Senior
# 3                  Dawn Bogart   F     B         Raw  42.0   Open Senior
# 4                 Destiny Dula   F    BD         Raw  18.0    Teen 18-19
# 5              Courtney Norris   F   SBD       Wraps  28.0   Open Senior
# 6                Maureen Clary   F   SBD         Raw  60.0     Mst 60-64
# 7                Maureen Clary   F   SBD         Raw  60.0   Open Senior
# 8       Priscilla Sweat Pardue   F   SBD       Wraps  52.0         50-54
# 9       Priscilla Sweat Pardue   F     D         Raw  52.0        Senior
# 10                Kayce Hoover   F   SBD       Wraps  24.0       Juniors
# 11                Cindy Meeker   F   SBD       Wraps  56.0     Mst 55-59
# 12                Cindy Meeker   F   SBD       Wraps  56.0   Open Senior
# 13       Candice Pardue Maness   F   SBD       Wraps  54.0     Mst 50-54
# 14              Danielle Ortiz   F   SBD         Raw  17.0    Teen 16-17
# 15             Jessica Jenkins   F   SBD   Multi-ply  32.0   Open Senior
# 16            Jessica Wissmann   F   SBD       Wraps  25.0   Open Senior
# 17                   Emma Love   F   SBD         Raw  18.0    Teen 18-19
# 18                Kelly Benson   F   SBD         Raw  22.0  Open Juniors
# 19              Cathy Cranford   F   SBD         Raw  56.0     Mst 55-59
# 20           Alexis Eliopoulos   F   SBD       Wraps  30.0        Senior
# 21                Shannon Nash   F     B         Raw  44.0   Open Senior
# 22                Paula Bowers   F   SBD       Wraps  34.0  Open Juniors
# 23             Kevin Gingerich   M   SBD         Raw  32.0  Open Juniors
# 24                  Juan Bollo   M   SBD         Raw  20.0  Open Juniors
# 25               James McManus   M   SBD       Wraps  36.0  Open Juniors
# 26               James McManus   M    BD         Raw  36.0  Open Juniors
# 27             Scott Faircloth   M   SBD       Wraps  27.0    Open M/P/F
# 28                 Justin Monk   M   SBD         Raw  22.0  Open Juniors
# 29                 Kevin Londe   M   SBD         Raw  23.0  Open Juniors
# ...                        ...  ..   ...         ...   ...           ...
# 911455              Fred Bland   M     B   Multi-ply   NaN         Elite
# 911456             James Matta   M     B   Multi-ply  40.5         Elite
# 911457             Greg Powell   M     B   Multi-ply   NaN         Elite
# 911458            Tony Carlino   M     B   Multi-ply  28.5         Elite
# 911459         David Kingwater   M     B   Multi-ply  44.5         Elite
# 911460               Bob Merkh   M     B   Multi-ply  32.5         Elite
# 911461         Dan Steltenkamp   M     B   Multi-ply  39.5         Elite
# 911462           Jonathan Byrd   M     B   Multi-ply  33.0         Elite
# 911463            Jesse Luczyk   M     B   Multi-ply  31.5         Elite
# 911464          Matt Magnivita   M     B   Multi-ply   NaN         Elite
# 911465       Katrina Bielomyza   F     D   Multi-ply  36.5         Elite
# 911466        Allison Lockhart   F     D   Multi-ply  33.5         Elite
# 911467            Diane Gmiter   F     D   Multi-ply   NaN         Elite
# 911468           Sheri Whetham   F     D   Multi-ply  54.5         Elite
# 911469            Molly Headly   F     D   Multi-ply   NaN         Elite
# 911470       Jessica Bowersock   F     D   Multi-ply  27.5         Elite
# 911471            Corey Miceli   M     D   Multi-ply  44.5         Elite
# 911472        Samantha Coleman   F     D   Multi-ply  36.0         Elite
# 911473         Bryan Doderdruk   M     D   Multi-ply   NaN         Elite
# 911474         Shawn Schumaker   M     D   Multi-ply   NaN         Elite
# 911475           Adam Colorado   M     D   Multi-ply   NaN         Elite
# 911476            Zane Geeting   M     D   Multi-ply   NaN         Elite
# 911477        Matthew Ladewski   M     D   Multi-ply   NaN         Elite
# 911478       Alastair MacNicol   M     D   Multi-ply   NaN         Elite
# 911479           Brian Yourist   M     D   Multi-ply  36.5         Elite
# 911480         William Barabas   M     D   Multi-ply  37.0         Elite
# 911481            Justin Zottl   M     D   Multi-ply  23.5         Elite
# 911482           Jake Anderson   M     D   Multi-ply   NaN         Elite
# 911483          Jeff Bumanglag   M     D   Multi-ply   NaN         Elite
# 911484           Shane Hammock   M     D   Multi-ply   NaN         Elite
#
#         BodyweightKg WeightClassKg  Squat1Kg  Squat2Kg  \
# 0              59.60            60     38.56     47.63
# 1              58.51            60    120.20    136.08
# 2              58.51            60    120.20    136.08
# 3              58.51            60       NaN       NaN
# 4              63.68          67.5       NaN       NaN
# 5              62.41          67.5    145.15    158.76
# 6              67.31          67.5    124.74   -138.35
# 7              67.31          67.5    124.74   -138.35
# 8              65.95          67.5    102.06    111.13
# 9              65.95          67.5       NaN       NaN
# 10             65.50          67.5    124.74    138.35
# 11             71.21            75    120.20   -129.27
# 12             71.21            75    120.20   -129.27
# 13             70.58            75     83.91     92.99
# 14             69.31            75     68.04     81.65
# 15             80.56          82.5    210.92    229.06
# 16             77.93          82.5    133.81    142.88
# 17             77.93          82.5     74.84     86.18
# 18             88.72            90    -86.18     86.18
# 19             83.10            90     68.04     79.38
# 20             88.36            90    154.22    165.56
# 21             83.64            90       NaN       NaN
# 22             94.80           90+    -74.84     74.84
# 23             71.94            75    129.27    140.61
# 24             70.67            75    151.95    158.76
# 25             74.93            75   -138.35   -151.95
# 26             74.93            75       NaN       NaN
# 27             71.30            75    165.56    181.44
# 28             79.65          82.5    136.08    149.69
# 29             80.10          82.5    183.70    190.51
# ...              ...           ...       ...       ...
# 911455         84.73            90       NaN       NaN
# 911456         97.98           100       NaN       NaN
# 911457         98.97           NaN       NaN       NaN
# 911458        109.23           110       NaN       NaN
# 911459        122.02           125       NaN       NaN
# 911460        124.38           125       NaN       NaN
# 911461        127.73           140       NaN       NaN
# 911462        131.72           140       NaN       NaN
# 911463        140.43          140+       NaN       NaN
# 911464        167.65          140+       NaN       NaN
# 911465         80.92          82.5       NaN       NaN
# 911466         81.47          82.5       NaN       NaN
# 911467         81.56          82.5       NaN       NaN
# 911468         83.91            90       NaN       NaN
# 911469         86.73            90       NaN       NaN
# 911470        111.22           90+       NaN       NaN
# 911471        127.73           140       NaN       NaN
# 911472        156.58           90+       NaN       NaN
# 911473         97.43           100       NaN       NaN
# 911474         98.79           100       NaN       NaN
# 911475         98.79           100       NaN       NaN
# 911476         99.70           100       NaN       NaN
# 911477         99.97           100       NaN       NaN
# 911478        102.24           110       NaN       NaN
# 911479        109.50           110       NaN       NaN
# 911480        113.58           125       NaN       NaN
# 911481        119.02           125       NaN       NaN
# 911482        120.29           125       NaN       NaN
# 911483        126.73           140       NaN       NaN
# 911484        129.46           140       NaN       NaN
#
#                               ...                          McCulloch  Tested  \
# 0                             ...                             167.76      No
# 1                             ...                             465.50      No
# 2                             ...                             465.50      No
# 3                             ...                             110.46      No
# 4                             ...                             138.29      No
# 5                             ...                             424.40      No
# 6                             ...                             525.25      No
# 7                             ...                             525.25      No
# 8                             ...                             342.80      No
# 9                             ...                             131.63      No
# 10                            ...                             354.89      No
# 11                            ...                             358.44      No
# 12                            ...                             358.44      No
# 13                            ...                             337.65      No
# 14                            ...                             267.45      No
# 15                            ...                             547.81      No
# 16                            ...                             322.30      No
# 17                            ...                             218.81      No
# 18                            ...                             262.85      No
# 19                            ...                             253.38      No
# 20                            ...                             428.59      No
# 21                            ...                             154.32      No
# 22                            ...                             182.50      No
# 23                            ...                             333.01      No
# 24                            ...                             366.71      No
# 25                            ...                                NaN      No
# 26                            ...                             194.06      No
# 27                            ...                             346.96      No
# 28                            ...                             335.59      No
# 29                            ...                             369.76      No
# ...                           ...                                ...     ...
# 911455                        ...                             163.04      No
# 911456                        ...                             161.10      No
# 911457                        ...                             212.37      No
# 911458                        ...                             227.06      No
# 911459                        ...                             174.74      No
# 911460                        ...                             193.94      No
# 911461                        ...                                NaN      No
# 911462                        ...                                NaN      No
# 911463                        ...                                NaN      No
# 911464                        ...                             179.63      No
# 911465                        ...                                NaN      No
# 911466                        ...                             208.37      No
# 911467                        ...                             212.77      No
# 911468                        ...                             220.22      No
# 911469                        ...                             193.20      No
# 911470                        ...                             166.30      No
# 911471                        ...                             218.98      No
# 911472                        ...                             192.04      No
# 911473                        ...                             216.85      No
# 911474                        ...                             223.24      No
# 911475                        ...                             189.60      No
# 911476                        ...                             198.03      No
# 911477                        ...                             197.82      No
# 911478                        ...                             184.03      No
# 911479                        ...                             182.69      No
# 911480                        ...                             202.60      No
# 911481                        ...                             185.77      No
# 911482                        ...                             211.17      No
# 911483                        ...                             181.85      No
# 911484                        ...                             205.18      No
#
#         AgeClass  Country  Glossbrenner  Federation        Date  MeetCountry  \
# 0          45-49      NaN        137.00   365Strong  2016-10-29          USA
# 1          40-44      NaN        403.37   365Strong  2016-10-29          USA
# 2          40-44      NaN        403.37   365Strong  2016-10-29          USA
# 3          40-44      NaN         95.71   365Strong  2016-10-29          USA
# 4          18-19      NaN        115.19   365Strong  2016-10-29          USA
# 5          24-34      NaN        374.79   365Strong  2016-10-29          USA
# 6          60-64      NaN        345.79   365Strong  2016-10-29          USA
# 7          60-64      NaN        345.79   365Strong  2016-10-29          USA
# 8          50-54      NaN        259.67   365Strong  2016-10-29          USA
# 9          50-54      NaN         99.71   365Strong  2016-10-29          USA
# 10         24-34      NaN        313.21   365Strong  2016-10-29          USA
# 11         55-59      NaN        253.47   365Strong  2016-10-29          USA
# 12         55-59      NaN        253.47   365Strong  2016-10-29          USA
# 13         50-54      NaN        247.15   365Strong  2016-10-29          USA
# 14         16-17      NaN        218.34   365Strong  2016-10-29          USA
# 15         24-34      NaN        480.23   365Strong  2016-10-29          USA
# 16         24-34      USA        283.04   365Strong  2016-10-29          USA
# 17         18-19      NaN        181.28   365Strong  2016-10-29          USA
# 18         20-23      NaN        226.51   365Strong  2016-10-29          USA
# 19         55-59      USA        177.91   365Strong  2016-10-29          USA
# 20         24-34   Greece        373.16   365Strong  2016-10-29          USA
# 21         40-44      USA        129.39   365Strong  2016-10-29          USA
# 22         24-34      NaN        157.78   365Strong  2016-10-29          USA
# 23         24-34      NaN        322.44   365Strong  2016-10-29          USA
# 24         20-23      NaN        344.88   365Strong  2016-10-29          USA
# 25         35-39      NaN           NaN   365Strong  2016-10-29          USA
# 26         35-39      NaN        187.72   365Strong  2016-10-29          USA
# 27         24-34      NaN        336.02   365Strong  2016-10-29          USA
# 28         20-23      NaN        321.00   365Strong  2016-10-29          USA
# 29         20-23      NaN        357.18   365Strong  2016-10-29          USA
# ...          ...      ...           ...         ...         ...          ...
# 911455       NaN      NaN        157.32         XPC  2017-03-03          USA
# 911456     40-44      NaN        154.92         XPC  2017-03-03          USA
# 911457       NaN      USA        204.17         XPC  2017-03-03          USA
# 911458     24-34      USA        217.57         XPC  2017-03-03          USA
# 911459       NaN      NaN        159.76         XPC  2017-03-03          USA
# 911460     24-34      NaN        184.78         XPC  2017-03-03          USA
# 911461       NaN      NaN           NaN         XPC  2017-03-03          USA
# 911462     24-34      USA           NaN         XPC  2017-03-03          USA
# 911463     24-34      NaN           NaN         XPC  2017-03-03          USA
# 911464       NaN      NaN        168.49         XPC  2017-03-03          USA
# 911465     35-39      NaN           NaN         XPC  2017-03-03          USA
# 911466     24-34      NaN        182.54         XPC  2017-03-03          USA
# 911467       NaN      NaN        186.39         XPC  2017-03-03          USA
# 911468       NaN   Canada        159.91         XPC  2017-03-03          USA
# 911469       NaN      NaN        168.48         XPC  2017-03-03          USA
# 911470     24-34      NaN        141.49         XPC  2017-03-03          USA
# 911471       NaN      NaN        199.77         XPC  2017-03-03          USA
# 911472     35-39      USA        160.06         XPC  2017-03-03          USA
# 911473       NaN      NaN        208.56         XPC  2017-03-03          USA
# 911474       NaN      NaN        214.62         XPC  2017-03-03          USA
# 911475       NaN      NaN        182.28         XPC  2017-03-03          USA
# 911476       NaN      NaN        190.34         XPC  2017-03-03          USA
# 911477       NaN      NaN        190.12         XPC  2017-03-03          USA
# 911478       NaN      NaN        176.75         XPC  2017-03-03          USA
# 911479     35-39      USA        175.03         XPC  2017-03-03          USA
# 911480     35-39      NaN        193.82         XPC  2017-03-03          USA
# 911481       NaN   Canada        177.36         XPC  2017-03-03          USA
# 911482       NaN      NaN        201.50         XPC  2017-03-03          USA
# 911483       NaN      NaN        173.10         XPC  2017-03-03          USA
# 911484       NaN      NaN        195.11         XPC  2017-03-03          USA
#
#         MeetState                                           MeetName
# 0              NC  Junior & Senior National Powerlifting Champion...
# 1              NC  Junior & Senior National Powerlifting Champion...
# 2              NC  Junior & Senior National Powerlifting Champion...
# 3              NC  Junior & Senior National Powerlifting Champion...
# 4              NC  Junior & Senior National Powerlifting Champion...
# 5              NC  Junior & Senior National Powerlifting Champion...
# 6              NC  Junior & Senior National Powerlifting Champion...
# 7              NC  Junior & Senior National Powerlifting Champion...
# 8              NC  Junior & Senior National Powerlifting Champion...
# 9              NC  Junior & Senior National Powerlifting Champion...
# 10             NC  Junior & Senior National Powerlifting Champion...
# 11             NC  Junior & Senior National Powerlifting Champion...
# 12             NC  Junior & Senior National Powerlifting Champion...
# 13             NC  Junior & Senior National Powerlifting Champion...
# 14             NC  Junior & Senior National Powerlifting Champion...
# 15             NC  Junior & Senior National Powerlifting Champion...
# 16             NC  Junior & Senior National Powerlifting Champion...
# 17             NC  Junior & Senior National Powerlifting Champion...
# 18             NC  Junior & Senior National Powerlifting Champion...
# 19             NC  Junior & Senior National Powerlifting Champion...
# 20             NC  Junior & Senior National Powerlifting Champion...
# 21             NC  Junior & Senior National Powerlifting Champion...
# 22             NC  Junior & Senior National Powerlifting Champion...
# 23             NC  Junior & Senior National Powerlifting Champion...
# 24             NC  Junior & Senior National Powerlifting Champion...
# 25             NC  Junior & Senior National Powerlifting Champion...
# 26             NC  Junior & Senior National Powerlifting Champion...
# 27             NC  Junior & Senior National Powerlifting Champion...
# 28             NC  Junior & Senior National Powerlifting Champion...
# 29             NC  Junior & Senior National Powerlifting Champion...
# ...           ...                                                ...
# 911455         OH                                             Finals
# 911456         OH                                             Finals
# 911457         OH                                             Finals
# 911458         OH                                             Finals
# 911459         OH                                             Finals
# 911460         OH                                             Finals
# 911461         OH                                             Finals
# 911462         OH                                             Finals
# 911463         OH                                             Finals
# 911464         OH                                             Finals
# 911465         OH                                             Finals
# 911466         OH                                             Finals
# 911467         OH                                             Finals
# 911468         OH                                             Finals
# 911469         OH                                             Finals
# 911470         OH                                             Finals
# 911471         OH                                             Finals
# 911472         OH                                             Finals
# 911473         OH                                             Finals
# 911474         OH                                             Finals
# 911475         OH                                             Finals
# 911476         OH                                             Finals
# 911477         OH                                             Finals
# 911478         OH                                             Finals
# 911479         OH                                             Finals
# 911480         OH                                             Finals
# 911481         OH                                             Finals
# 911482         OH                                             Finals
# 911483         OH                                             Finals
# 911484         OH                                             Finals
#
# [911485 rows x 36 columns]

# %%
df.iloc[0]
# Out:
# Name                                                Angie Belk Terry
# Sex                                                                F
# Event                                                            SBD
# Equipment                                                      Wraps
# Age                                                               47
# Division                                                   Mst 45-49
# BodyweightKg                                                    59.6
# WeightClassKg                                                     60
# Squat1Kg                                                       38.56
# Squat2Kg                                                       47.63
# Squat3Kg                                                      -54.43
# Squat4Kg                                                         NaN
# Best3SquatKg                                                   47.63
# Bench1Kg                                                       15.88
# Bench2Kg                                                       20.41
# Bench3Kg                                                      -24.95
# Bench4Kg                                                         NaN
# Best3BenchKg                                                   20.41
# Deadlift1Kg                                                    61.23
# Deadlift2Kg                                                    70.31
# Deadlift3Kg                                                   -77.11
# Deadlift4Kg                                                      NaN
# Best3DeadliftKg                                                70.31
# TotalKg                                                       138.35
# Place                                                              1
# Wilks                                                         155.05
# McCulloch                                                     167.76
# Tested                                                            No
# AgeClass                                                       45-49
# Country                                                          NaN
# Glossbrenner                                                     137
# Federation                                                 365Strong
# Date                                                      2016-10-29
# MeetCountry                                                      USA
# MeetState                                                         NC
# MeetName           Junior & Senior National Powerlifting Champion...
# Name: 0, dtype: object

# %% [markdown]
# # Dealing with DataFrame Attributes

# %%
df.columns
# Out:
# Index(['Name', 'Sex', 'Event', 'Equipment', 'Age', 'Division', 'BodyweightKg',
#        'WeightClassKg', 'Squat1Kg', 'Squat2Kg', 'Squat3Kg', 'Squat4Kg',
#        'Best3SquatKg', 'Bench1Kg', 'Bench2Kg', 'Bench3Kg', 'Bench4Kg',
#        'Best3BenchKg', 'Deadlift1Kg', 'Deadlift2Kg', 'Deadlift3Kg',
#        'Deadlift4Kg', 'Best3DeadliftKg', 'TotalKg', 'Place', 'Wilks',
#        'McCulloch', 'Tested', 'AgeClass', 'Country', 'Glossbrenner',
#        'Federation', 'Date', 'MeetCountry', 'MeetState', 'MeetName'],
#       dtype='object')

# %% [markdown]
# ## Print the Various Attributes

# %%
df['Federation'].unique()
# Out:
# array(['365Strong', 'AAP', 'AAU', 'ACHIPO', 'ADAU', 'ADFPA', 'ADFPF',
#        'AEP', 'AFPF', 'AfricanPF', 'AmericanSA', 'APA', 'WPA', 'APC',
#        'WPC', 'APF', 'CAPO', 'APU', 'AsianPF', 'Atlantis', 'AusPL',
#        'BAWLA', 'BB', 'BDFPA', 'BP', 'EPA', 'BPC', 'BPU', 'BVDK',
#        'CAPO-NZ', 'CAST', 'ChinaPA', 'CommonwealthPF', 'CPA', 'CPC',
#        'CPF', 'CPL', 'CPO', 'CPU', 'Croatia-UA', 'CSST', 'DSF', 'EPF',
#        'FALPO', 'FCST', 'FEMEPO', 'FEPOA', 'FESUPO', 'FFForce', 'FPO',
#        'FPR', 'GoldenDouble', 'GPA', 'MPA', 'GPA-CRO', 'GPC', 'GPC-AUS',
#        'GPC-CAN', 'GPC-GB', 'GPC-IRL', 'GPC-LAT', 'GPC-NZ', 'GPC-RUS',
#        'GPF', 'GPU', 'Hardcore', 'HERC', 'HPLS', 'HPLS-UA', 'HPO', 'IBSA',
#        'IDFPF', 'IKF', 'IPA', 'IPC', 'IPF', 'IPL-NZ', 'IrishPF',
#        'IrishPO', 'IRP', 'JPA', 'KPF', 'KRAFT', 'LPF', 'MHP', 'MM', 'NAP',
#        'NAPF', 'NASA', 'NIPF', 'NORCAL', 'NordicPF', 'NOTLD', 'NPA',
#        'NPB', 'NSF', 'NZOpen', 'NZPF', 'OceaniaPF', 'OlomouckySilak',
#        'ORPF', 'PA', 'PAP', 'ParaPL', 'USPF', 'AAPLF', 'WDFPF', 'BBDD',
#        'WNPF', 'AIWBPA', 'BPF', 'WBC', 'AusDFPF', 'USAPL', 'BPO', 'SCI',
#        'WABDL', 'UPA', 'PLZS', 'PRIDE', 'ProRaw', 'PRPA', 'PZKFiTS',
#        'RAW', 'RAW-CAN', 'IDFPA', 'RAW-Iceland', 'RAW-UKR', 'RAWU', 'RPS',
#        'XPC', 'IPL', 'RPU', 'WRPF', 'RUPC', 'ScottishPL', 'SCT', 'SPA',
#        'SPF', 'SPSS', 'SSA', 'SSF', 'SVNL', 'ThaiPF', 'THSPA',
#        'UkrainePA', 'UkrainePF', 'UkrainePO', 'UPC', 'USPA', 'USPS',
#        'USSF', 'VietnamPA', 'Vityaz', 'WelshPA', 'WP', 'WPA-RUS', 'WPAU',
#        'WPC-Finland', 'WPC-Germany', 'WPC-Iceland', 'WPC-KAZ',
#        'WPC-Latvia', 'WPC-Moldova', 'WPC-Portugal', 'WPC-RUS', 'WPC-UKR',
#        'WPF', 'WPU', 'WPUF', 'WRPF-AUS', 'WRPF-CAN', 'WUAP', 'WUAP-AUT'],
#       dtype=object)

# %% [markdown]
# # Raw Tested Data

# %%
raw_tested = df[(df['Tested']=='Yes') & (df['Equipment']=='Raw') & (df['Federation']=='IPF')]

# %%
raw_tested
# Out:
#                      Name Sex Event Equipment   Age Division  BodyweightKg  \
# 236788  Andrzej Stanaszek   M   SBD       Raw  28.5     Open         51.50
# 237421     Chen-Yen Huang   F     B       Raw  19.5     Open         40.00
# 237422    Elvira Kosareva   F     B       Raw  59.5     Open         40.00
# 237423          Li-Hua Lu   F     B       Raw  29.5     Open         43.00
# 237424       Anna Orosova   F     B       Raw  36.5     Open         48.00
# 237425      Ying-Hui Chen   F     B       Raw  19.5     Open         44.20
# 237426    Maria Bartosova   F     B       Raw  38.5     Open         55.50
# 237427       Ya-Hsuan Lin   F     B       Raw  23.5     Open         55.10
# 237428        Tzu-Hui Lin   F     B       Raw  18.5     Open         79.80
# 237429  Ludmil Yedukonene   F     B       Raw  24.5     Open         86.70
# 237430   Larissa Riadnova   F     B       Raw  55.5     Open         84.60
# 237431   Vitaliy Kursenov   M     B       Raw  30.5     Open         47.20
# 237432       Boman Hommes   M     B       Raw  37.5     Open         43.10
# 237433    Chia-Tung Chang   M     B       Raw  19.5     Open         51.60
# 237434     Chi-Ching Chen   M     B       Raw  32.5     Open         55.20
# 237435     Maxim Bogdanov   M     B       Raw  42.5     Open         54.70
# 237436       Gunar Huppke   M     B       Raw  25.5     Open         56.00
# 237437        István Tóth   M     B       Raw  43.5     Open         58.80
# 237438        Erwin Ersek   M     B       Raw  31.5     Open         59.30
# 237439    Philippe Herzog   M     B       Raw  38.5     Open         66.60
# 237440      Mikulas Lacek   M     B       Raw  20.5     Open         67.40
# 237441     Roman Navratil   M     B       Raw  46.5     Open         66.80
# 237442       Martin Skupa   M     B       Raw  19.5     Open         66.20
# 237443    Cheng-Lung Yang   M     B       Raw  37.5     Open         69.90
# 237444  Gerhard Leierzopf   M     B       Raw  38.5     Open         72.60
# 237445     Yuriy Povetkin   M     B       Raw  60.5     Open         68.40
# 237446      Petr Szalacsi   M     B       Raw  43.5     Open         68.50
# 237447      Jozef Johanes   M     B       Raw  35.5     Open         72.10
# 237448    Vladislav Vasek   M     B       Raw  50.5     Open         75.50
# 237449         Jan Kubosi   M     B       Raw  29.5     Open         80.90
# ...                   ...  ..   ...       ...   ...      ...           ...
# 273516    Hsien-Chi Huang   M     B       Raw  29.5     Open        105.10
# 273517      Jarmo Ylineva   M     B       Raw  46.5     Open        110.90
# 273518       Steve Bennet   M     B       Raw  32.5     Open        127.40
# 413654  Andrzej Stanaszek   M   SBD       Raw  18.5      NaN         50.30
# 413993  Andrzej Stanaszek   M     B       Raw  18.5      NaN         52.00
# 414079        Arun Sondhi   M     B       Raw   NaN      NaN         48.00
# 414080        John Tyrell   M     B       Raw   NaN      NaN         48.00
# 414081      Ali Al Khatib   M     B       Raw   NaN      NaN         52.00
# 414082      Andreas Klein   M     B       Raw   NaN      NaN         56.00
# 414083       Mihaly Virag   M     B       Raw   NaN      NaN         67.50
# 414084          Ali Alper   M     B       Raw   NaN      NaN         67.50
# 414085  Michael Fauerbach   M     B       Raw   NaN      NaN         67.50
# 414086        Bernd Vogel   M     B       Raw  33.5      NaN         75.00
# 414087        Nick Slater   M     B       Raw   NaN      NaN         82.50
# 414088   Béla Bolgárfalvi   M     B       Raw  46.5      NaN         82.50
# 414089        Edward Worm   M     B       Raw   NaN      NaN         82.50
# 414090          Tim Toner   M     B       Raw   NaN      NaN         90.00
# 414091     Fred Mackenzie   M     B       Raw  52.5      NaN         90.00
# 414092      Istvan Nanasi   M     B       Raw   NaN      NaN        100.00
# 414093      Max Bergbauer   M     B       Raw  54.5      NaN        100.00
# 414094        Tony Bishop   M     B       Raw   NaN      NaN           NaN
# 414095    Ernst Nasgowitz   M     B       Raw   NaN      NaN           NaN
# 416543  Andrzej Stanaszek   M   SBD       Raw  19.5      NaN         47.80
# 416964  Andrzej Stanaszek   M     B       Raw  19.5     Open         52.00
# 420404  Andrzej Stanaszek   M   SBD       Raw  20.5     Open         49.50
# 422085  Andrzej Stanaszek   M     B       Raw  20.5     Open         52.00
# 425892  Andrzej Stanaszek   M   SBD       Raw  21.5     Open         51.45
# 426424  Andrzej Stanaszek   M     B       Raw  21.5      NaN         51.00
# 429076  Andrzej Stanaszek   M   SBD       Raw  22.5      NaN         50.60
# 432338  Andrzej Stanaszek   M   SBD       Raw  23.5      NaN         49.90
#
#        WeightClassKg  Squat1Kg  Squat2Kg  \
# 236788            52       NaN       NaN
# 237421            40       NaN       NaN
# 237422            40       NaN       NaN
# 237423            44       NaN       NaN
# 237424            48       NaN       NaN
# 237425            48       NaN       NaN
# 237426            56       NaN       NaN
# 237427            56       NaN       NaN
# 237428          82.5       NaN       NaN
# 237429            90       NaN       NaN
# 237430            90       NaN       NaN
# 237431            48       NaN       NaN
# 237432            48       NaN       NaN
# 237433            52       NaN       NaN
# 237434            56       NaN       NaN
# 237435            56       NaN       NaN
# 237436            56       NaN       NaN
# 237437            60       NaN       NaN
# 237438            60       NaN       NaN
# 237439          67.5       NaN       NaN
# 237440          67.5       NaN       NaN
# 237441          67.5       NaN       NaN
# 237442          67.5       NaN       NaN
# 237443            75       NaN       NaN
# 237444            75       NaN       NaN
# 237445            75       NaN       NaN
# 237446            75       NaN       NaN
# 237447            75       NaN       NaN
# 237448          82.5       NaN       NaN
# 237449          82.5       NaN       NaN
# ...              ...       ...       ...
# 273516          100+       NaN       NaN
# 273517          100+       NaN       NaN
# 273518          100+       NaN       NaN
# 413654            52     190.0    -220.0
# 413993            52       NaN       NaN
# 414079            48       NaN       NaN
# 414080            48       NaN       NaN
# 414081            52       NaN       NaN
# 414082            56       NaN       NaN
# 414083          67.5       NaN       NaN
# 414084          67.5       NaN       NaN
# 414085          67.5       NaN       NaN
# 414086            75       NaN       NaN
# 414087          82.5       NaN       NaN
# 414088          82.5       NaN       NaN
# 414089          82.5       NaN       NaN
# 414090            90       NaN       NaN
# 414091            90       NaN       NaN
# 414092           100       NaN       NaN
# 414093           100       NaN       NaN
# 414094          100+       NaN       NaN
# 414095          100+       NaN       NaN
# 416543            52     195.0     210.0
# 416964            52       NaN       NaN
# 420404            52     195.0     242.5
# 422085            52       NaN       NaN
# 425892            52     195.0     242.5
# 426424            52       NaN       NaN
# 429076            52     240.0     270.0
# 432338            52     250.0    -260.0
#
#                           ...                     McCulloch  Tested  AgeClass  \
# 236788                    ...                        574.95     Yes     24-34
# 237421                    ...                         93.20     Yes       NaN
# 237422                    ...                         63.83     Yes       NaN
# 237423                    ...                        121.51     Yes     24-34
# 237424                    ...                         96.02     Yes     35-39
# 237425                    ...                         87.60     Yes       NaN
# 237426                    ...                         85.91     Yes     35-39
# 237427                    ...                         80.44     Yes       NaN
# 237428                    ...                        111.70     Yes     18-19
# 237429                    ...                         61.48     Yes     24-34
# 237430                    ...                         57.15     Yes     55-59
# 237431                    ...                        125.45     Yes     24-34
# 237432                    ...                        118.44     Yes     35-39
# 237433                    ...                        144.04     Yes       NaN
# 237434                    ...                        129.27     Yes     24-34
# 237435                    ...                        111.67     Yes     40-44
# 237436                    ...                         91.03     Yes     24-34
# 237437                    ...                        120.94     Yes     40-44
# 237438                    ...                         79.75     Yes     24-34
# 237439                    ...                        126.65     Yes     35-39
# 237440                    ...                         89.45     Yes     20-23
# 237441                    ...                         91.34     Yes     45-49
# 237442                    ...                         73.31     Yes       NaN
# 237443                    ...                        114.41     Yes     35-39
# 237444                    ...                        102.10     Yes     35-39
# 237445                    ...                        132.91     Yes     60-64
# 237446                    ...                         78.57     Yes     40-44
# 237447                    ...                         64.13     Yes     35-39
# 237448                    ...                         98.18     Yes     50-54
# 237449                    ...                         76.27     Yes     24-34
# ...                       ...                           ...     ...       ...
# 273516                    ...                         83.63     Yes     24-34
# 273517                    ...                         83.07     Yes     45-49
# 273518                    ...                         53.93     Yes     24-34
# 413654                    ...                        479.51     Yes     18-19
# 413993                    ...                        153.42     Yes     18-19
# 414079                    ...                        112.38     Yes       NaN
# 414080                    ...                         56.19     Yes       NaN
# 414081                    ...                        127.57     Yes       NaN
# 414082                    ...                         75.10     Yes       NaN
# 414083                    ...                        104.09     Yes       NaN
# 414084                    ...                         98.30     Yes       NaN
# 414085                    ...                         69.39     Yes       NaN
# 414086                    ...                        128.26     Yes     24-34
# 414087                    ...                        115.56     Yes       NaN
# 414088                    ...                        116.26     Yes     45-49
# 414089                    ...                         50.24     Yes       NaN
# 414090                    ...                         87.78     Yes       NaN
# 414091                    ...                         96.68     Yes     50-54
# 414092                    ...                        115.63     Yes       NaN
# 414093                    ...                        109.91     Yes       NaN
# 414094                    ...                           NaN     Yes       NaN
# 414095                    ...                           NaN     Yes       NaN
# 416543                    ...                        556.39     Yes       NaN
# 416964                    ...                        153.08     Yes       NaN
# 420404                    ...                        570.02     Yes     20-23
# 422085                    ...                        154.13     Yes     20-23
# 425892                    ...                        574.40     Yes     20-23
# 426424                    ...                        160.91     Yes     20-23
# 429076                    ...                        589.16     Yes     20-23
# 432338                    ...                        581.91     Yes       NaN
#
#             Country  Glossbrenner  Federation        Date   MeetCountry  \
# 236788       Poland        565.24         IPF  2000-11-15         Japan
# 237421       Taiwan         81.47         IPF  2000-12-08       Czechia
# 237422       Russia         44.13         IPF  2000-12-08       Czechia
# 237423       Taiwan        109.28         IPF  2000-12-08       Czechia
# 237424     Slovakia         85.47         IPF  2000-12-08       Czechia
# 237425       Taiwan         75.51         IPF  2000-12-08       Czechia
# 237426     Slovakia         76.00         IPF  2000-12-08       Czechia
# 237427       Taiwan         71.17         IPF  2000-12-08       Czechia
# 237428       Taiwan         92.42         IPF  2000-12-08       Czechia
# 237429      Belarus         53.62         IPF  2000-12-08       Czechia
# 237430       Russia         40.76         IPF  2000-12-08       Czechia
# 237431       Russia        124.16         IPF  2000-12-08       Czechia
# 237432  Netherlands        118.18         IPF  2000-12-08       Czechia
# 237433       Taiwan        136.14         IPF  2000-12-08       Czechia
# 237434       Taiwan        126.51         IPF  2000-12-08       Czechia
# 237435       Russia        107.20         IPF  2000-12-08       Czechia
# 237436      Germany         89.02         IPF  2000-12-08       Czechia
# 237437      Hungary        114.41         IPF  2000-12-08       Czechia
# 237438      Hungary         77.75         IPF  2000-12-08       Czechia
# 237439  Switzerland        122.90         IPF  2000-12-08       Czechia
# 237440     Slovakia         84.24         IPF  2000-12-08       Czechia
# 237441      Czechia         82.99         IPF  2000-12-08       Czechia
# 237442      Czechia         68.42         IPF  2000-12-08       Czechia
# 237443       Taiwan        110.86         IPF  2000-12-08       Czechia
# 237444      Austria         98.83         IPF  2000-12-08       Czechia
# 237445       Russia         96.17         IPF  2000-12-08       Czechia
# 237446      Czechia         73.89         IPF  2000-12-08       Czechia
# 237447     Slovakia         62.09         IPF  2000-12-08       Czechia
# 237448      Czechia         84.04         IPF  2000-12-08       Czechia
# 237449     Slovakia         73.66         IPF  2000-12-08       Czechia
# ...             ...           ...         ...         ...           ...
# 273516       Taiwan         80.25         IPF  1999-12-09       Finland
# 273517      Finland         74.49         IPF  1999-12-09       Finland
# 273518           UK         51.32         IPF  1999-12-09       Finland
# 413654       Poland        445.49         IPF  1990-11-14   Netherlands
# 413993       Poland        142.20         IPF  1990-12-16       Germany
# 414079       Sweden        111.08         IPF  1990-12-16       Germany
# 414080           UK         55.54         IPF  1990-12-16       Germany
# 414081          NaN        125.33         IPF  1990-12-16       Germany
# 414082          NaN         73.44         IPF  1990-12-16       Germany
# 414083      Hungary        100.96         IPF  1990-12-16       Germany
# 414084          NaN         95.35         IPF  1990-12-16       Germany
# 414085      Germany         67.31         IPF  1990-12-16       Germany
# 414086      Germany        124.07         IPF  1990-12-16       Germany
# 414087          NaN        111.56         IPF  1990-12-16       Germany
# 414088      Hungary        105.09         IPF  1990-12-16       Germany
# 414089          NaN         48.50         IPF  1990-12-16       Germany
# 414090           UK         84.59         IPF  1990-12-16       Germany
# 414091           UK         79.98         IPF  1990-12-16       Germany
# 414092          NaN        111.13         IPF  1990-12-16       Germany
# 414093      Germany         87.73         IPF  1990-12-16       Germany
# 414094           UK           NaN         IPF  1990-12-16       Germany
# 414095      Germany           NaN         IPF  1990-12-16       Germany
# 416543       Poland        528.96         IPF  1991-11-14        Sweden
# 416964       Poland        144.61         IPF  1991-12-15       Germany
# 420404       Poland        545.66         IPF  1992-11-19       England
# 422085       Poland        147.02         IPF  1992-12-08        Taiwan
# 425892       Poland        553.67         IPF  1993-11-27        Sweden
# 426424       Poland        155.20         IPF  1993-12-12       Hungary
# 429076       Poland        574.20         IPF  1994-11-17  South Africa
# 432338       Poland        573.40         IPF  1995-11-15       Finland
#
#         MeetState                                  MeetName
# 236788        NaN    Men's World Powerlifting Championships
# 237421        NaN  World Disabled Bench Press Championships
# 237422        NaN  World Disabled Bench Press Championships
# 237423        NaN  World Disabled Bench Press Championships
# 237424        NaN  World Disabled Bench Press Championships
# 237425        NaN  World Disabled Bench Press Championships
# 237426        NaN  World Disabled Bench Press Championships
# 237427        NaN  World Disabled Bench Press Championships
# 237428        NaN  World Disabled Bench Press Championships
# 237429        NaN  World Disabled Bench Press Championships
# 237430        NaN  World Disabled Bench Press Championships
# 237431        NaN  World Disabled Bench Press Championships
# 237432        NaN  World Disabled Bench Press Championships
# 237433        NaN  World Disabled Bench Press Championships
# 237434        NaN  World Disabled Bench Press Championships
# 237435        NaN  World Disabled Bench Press Championships
# 237436        NaN  World Disabled Bench Press Championships
# 237437        NaN  World Disabled Bench Press Championships
# 237438        NaN  World Disabled Bench Press Championships
# 237439        NaN  World Disabled Bench Press Championships
# 237440        NaN  World Disabled Bench Press Championships
# 237441        NaN  World Disabled Bench Press Championships
# 237442        NaN  World Disabled Bench Press Championships
# 237443        NaN  World Disabled Bench Press Championships
# 237444        NaN  World Disabled Bench Press Championships
# 237445        NaN  World Disabled Bench Press Championships
# 237446        NaN  World Disabled Bench Press Championships
# 237447        NaN  World Disabled Bench Press Championships
# 237448        NaN  World Disabled Bench Press Championships
# 237449        NaN  World Disabled Bench Press Championships
# ...           ...                                       ...
# 273516        NaN  World Disabled Bench Press Championships
# 273517        NaN  World Disabled Bench Press Championships
# 273518        NaN  World Disabled Bench Press Championships
# 413654        NaN    Men's World Powerlifting Championships
# 413993        NaN           World Bench Press Championships
# 414079        NaN  World Disabled Bench Press Championships
# 414080        NaN  World Disabled Bench Press Championships
# 414081        NaN  World Disabled Bench Press Championships
# 414082        NaN  World Disabled Bench Press Championships
# 414083        NaN  World Disabled Bench Press Championships
# 414084        NaN  World Disabled Bench Press Championships
# 414085        NaN  World Disabled Bench Press Championships
# 414086        NaN  World Disabled Bench Press Championships
# 414087        NaN  World Disabled Bench Press Championships
# 414088        NaN  World Disabled Bench Press Championships
# 414089        NaN  World Disabled Bench Press Championships
# 414090        NaN  World Disabled Bench Press Championships
# 414091        NaN  World Disabled Bench Press Championships
# 414092        NaN  World Disabled Bench Press Championships
# 414093        NaN  World Disabled Bench Press Championships
# 414094        NaN  World Disabled Bench Press Championships
# 414095        NaN  World Disabled Bench Press Championships
# 416543        NaN    Men's World Powerlifting Championships
# 416964        NaN           World Bench Press Championships
# 420404        NaN     World Men's Powerlifting Championship
# 422085        NaN           World Bench Press Championships
# 425892        NaN          World Powerlifting Championships
# 426424        NaN           World Bench Press Championships
# 429076        NaN    Men's World Powerlifting Championships
# 432338        NaN    Men's World Powerlifting Championships
#
# [5750 rows x 36 columns]

# %%
raw_tested_male = raw_tested[raw_tested['Sex']=='M']

# %% [markdown]
# Compare the bench press, squat, and deadlift of raw tested males.

# %%
fig, ax = plt.subplots(1, 3, figsize=(15,4))

ax[0].hist(raw_tested_male['Best3SquatKg'][raw_tested_male['Best3SquatKg']>0], bins=50)
ax[1].hist(raw_tested_male['Best3BenchKg'][raw_tested_male['Best3BenchKg']>0], bins=50, color='r')
ax[2].hist(raw_tested_male['Best3DeadliftKg'][raw_tested_male['Best3DeadliftKg']>0], bins=50, color='g')

ax[0].grid()
ax[1].grid()
ax[2].grid()

ax[0].set_title('Squat')
ax[1].set_title('Bench')
ax[2].set_title('Deadlift')

ax[0].set_xlabel('Weight Lifted (kg)')
ax[1].set_xlabel('Weight Lifted (kg)')
ax[2].set_xlabel('Weight Lifted (kg)')

ax[0].set_ylabel('Frequency')

plt.show()

# %% [markdown]
# # Total Lifts as a Function of Weight

# %% [markdown]
# Only take data when lifter completed all three lifts.

# %%
raw_tested_male_all3 = raw_tested_male[(raw_tested_male['Best3SquatKg']>0) &
                                       (raw_tested_male['Best3BenchKg']>0) &
                                       (raw_tested_male['Best3DeadliftKg']>0) &
                                      (raw_tested_male['BodyweightKg']>50) & 
                                       (raw_tested_male['BodyweightKg']<150)]

raw_tested_male_all3 = raw_tested_male_all3.dropna(subset=['BodyweightKg', 'TotalKg'])

# %% [markdown]
# Plot preliminary data.

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(raw_tested_male_all3['BodyweightKg'], raw_tested_male_all3['TotalKg'], alpha=0.05, s=1)
ax.set_ylabel('Total Weight Lifted (kg)')
ax.set_xlabel('Body Weight (kg)')

ax.set_title('Total Weight Lifted as a Function of Bodyweight (Raw Tested Males)')
ax.grid()

plt.show()

# %% [markdown]
# ## Do Some Curve Fitting

# %% [markdown]
# Obtain the body weight and lifted weight.

# %%
bw = np.array(raw_tested_male_all3['BodyweightKg'])
lw = np.array(raw_tested_male_all3['TotalKg'])

# %% [markdown]
# The logaritmic function we're fitting to:

# %%
def func(x, a, b):
    return a+b*x

popt, pcov = curve_fit(func, np.log(bw), lw)
a_log, b_log = popt[0], popt[1]

popt, pcov = curve_fit(func, bw, lw)
a_lin, b_lin = popt[0], popt[1]

# %%
x = np.linspace(50, 200, 1000)

# %% [markdown]
# Compare linear vs logarithmic best fit line.

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(raw_tested_male_all3['BodyweightKg'], raw_tested_male_all3['TotalKg'], alpha=0.05, s=1)
ax.set_ylabel('Total Weight Lifted (kg)')
ax.set_xlabel('Body Weight (kg)')
ax.plot(x, a_log+b_log*np.log(x), color='r',label='Logarithmic Curve')
ax.plot(x, a_lin+b_lin*x, color='g', label='Linear Curve')

ax.set_title('Total Weight Lifted as a Function of Bodyweight (Raw Tested Males)')
ax.set_ylim(0, 1000)
ax.grid()

plt.show()

# %% [markdown]
# ## Proposed Solution to Wilks

# %%
a=-216.0475144
b=16.2606339
c=-0.002388645
d=-0.00113732
e=7.01863E-06
f=-1.291E-08

def wilks(lw, bw):
    return 500*lw/(a+b*bw+c*bw**2+d*bw**3+e*bw**4+f*bw**5)

def lifted_weight_wilks(wilks, bw):
    return (a+b*bw+c*bw**2+d*bw**3+e*bw**4+f*bw**5)*wilks/500

def points(lw, bw):
    avg_weight = a_log+b_log*np.log(bw)
    
    
def lifted_weight_points(points, bw):
    return

# %%
lifted_weight(350, 59)
# Out:
# 404.0756782372381

# %% [markdown]
# Treat the scoring system like IQ. 300 is the mean, 75 is standard deviation. First find the standard deviation (relaitve to our proposed log curve).

# %%
S = sum((lwi - (a_log+b_log*np.log(bwi)))**2 for (bwi, lwi) in zip(bw, lw))
std_dev = np.sqrt( S/(len(bw)+1))

# %% [markdown]
# Plots:

# %%
fig, ax = plt.subplots(figsize=(12,6))

ax.scatter(raw_tested_male_all3['BodyweightKg'], raw_tested_male_all3['TotalKg'], alpha=0.05, s=1, label='')
ax.set_ylabel('Total Weight Lifted (kg)')
ax.set_xlabel('Body Weight (kg)')
ax.plot(x, a_log+b_log*np.log(x), color='k', lw=5)
ax.plot(x, std_dev+a_log+b_log*np.log(x), color='r', label='$1\sigma$')
ax.plot(x, -std_dev+a_log+b_log*np.log(x), color='r')
ax.plot(x, 2*std_dev+a_log+b_log*np.log(x), color='g', label='$2\sigma$')
ax.plot(x, -2*std_dev+a_log+b_log*np.log(x), color='g')

ax.legend(loc='best')

ax.set_title('Total Weight Lifted as a Function of Bodyweight (Raw Tested Males)')
ax.set_ylim(0, 1000)
ax.grid()

plt.show()

# %% [markdown]
# ## Obtain All Weight Classes

# %%
df1 = raw_tested_male_all3[(raw_tested_male_all3['BodyweightKg']<59)]
df2 = raw_tested_male_all3[(raw_tested_male_all3['BodyweightKg']>59) & (raw_tested_male_all3['BodyweightKg']<66)]
df3 = raw_tested_male_all3[(raw_tested_male_all3['BodyweightKg']>66) & (raw_tested_male_all3['BodyweightKg']<74)]
df4 = raw_tested_male_all3[(raw_tested_male_all3['BodyweightKg']>74) & (raw_tested_male_all3['BodyweightKg']<83)]
df5 = raw_tested_male_all3[(raw_tested_male_all3['BodyweightKg']>83) & (raw_tested_male_all3['BodyweightKg']<93)]
df6 = raw_tested_male_all3[(raw_tested_male_all3['BodyweightKg']>93) & (raw_tested_male_all3['BodyweightKg']<105)]
df7 = raw_tested_male_all3[(raw_tested_male_all3['BodyweightKg']>105) & (raw_tested_male_all3['BodyweightKg']<120)]
df8 = raw_tested_male_all3[(raw_tested_male_all3['BodyweightKg']>120)]

dfs = [(df1, 59), (df2, 66), (df3, 74), (df4, 83), (df5, 93), (df6, 105), (df7, 120), (df8, 150)]

# %% [markdown]
# ## See How Logarithmic Model Holds Up

# %%
def get_prop_over_n(lw_arr, freq_arr, bw, wilks):
    idx = (np.abs(lw_arr - lifted_weight(wilks, bw))).argmin()
    return np.trapz(freq_arr[idx:], lw_arr[idx:])

# %%
prop_over_500_wilks = []
prop_over_500_points = []

fig, ax = plt.subplots(8,2,figsize=(12,32))

for (i, df) in enumerate(dfs):
    
    (lw_arr, freq_arr) = sns.distplot(df[0]['TotalKg'], bins=25, ax=ax[i][0]).get_lines()[0].get_data()
    prop_over_500_wilks.append(get_prop_over_n(np.array(lw_arr), np.array(freq_arr), df[1], 500))
    sns.distplot(df[0]['TotalKg'], bins=25, ax=ax[i][1])
    
    ax[i][0].set_xlabel('Weight Lifted (Kg)')
    ax[i][0].set_ylabel('Frequency')
    ax[i][0].set_title('Total Weight Lifted {}Kg Weight Class'.format(df[1]))
    ax[i][1].set_xlabel('Weight Lifted (Kg)')
    ax[i][1].set_ylabel('Frequency')
    ax[i][1].set_title('Total Weight Lifted {}Kg Weight Class'.format(df[1]))

    ax[i][0].axvline(a_log+b_log*np.log(df[1]), color='k', label = '$300$ points')
    ax[i][0].axvline(std_dev+a_log+b_log*np.log(df[1]), color='r', label='$300 \pm 100$ points')
    ax[i][0].axvline(-std_dev+a_log+b_log*np.log(df[1]), color='r')
    ax[i][0].axvline(2*std_dev+a_log+b_log*np.log(df[1]), color='g', label='$300 \pm 200$ points')
    ax[i][0].axvline(-2*std_dev+a_log+b_log*np.log(df[1]), color='g')
    
    ax[i][1].axvline(lifted_weight(350, df[1]), color='k', label='350 Wilks')
    ax[i][1].axvline(lifted_weight(400, df[1]), color='r', label='400 Wilks')
    ax[i][1].axvline(lifted_weight(500, df[1]), color='g', label='500 Wilks')

    ax[i][0].grid()
    ax[i][0].legend(loc='best')
    ax[i][1].grid()
    ax[i][1].legend(loc='best')


fig.tight_layout()
plt.show()
# Out:
# /Users/lukepolson/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %% [markdown]
# Now we look at the percent of lifters in each weight class about above 500 points and 500
# wilks respectively (the outliers). We want an equal proportion for all weight classes since 450 should signify "elite" lifters and there should be equal proportions in each weight catagory.

# %%
print(prop_over_500_wilks)
# Out:
# [0.015435353254822416, 0.009603902600393403, 0.003401239096351414, 0.003167154366804162, 0.0034602891750592376, 0.003937796002868839, 0.007981021476627182, 0.011081216733805153]
