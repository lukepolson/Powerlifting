# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy as sp
import glob, os
from scipy import misc
import seaborn as sns

# %%
df = pd.read_csv('openpowerlifting.csv')
# Out:
# /Users/lukepolson/anaconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2698: DtypeWarning: Columns (34) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
inter = df[(df['Sex']=='M') & (df['Division'] == 'Junior') & (df['Equipment'] == 'Raw')]
inter
# Out:
#                          Name Sex Event Equipment   Age Division  \
# 2882            Luis Muñoz #3   M     B       Raw  21.0   Junior
# 2886      Christian Sepúlveda   M     B       Raw  23.0   Junior
# 2897        Juan Hernández #1   M    BD       Raw  22.0   Junior
# 2904          Anibal Mardones   M    BD       Raw  22.0   Junior
# 2906         Jeremías Paredes   M    BD       Raw  22.0   Junior
# 2923           Roberto Guzman   M     D       Raw  22.0   Junior
# 3088           Brent A. Wrenn   M   SBD       Raw   NaN   Junior
# 3093            Bryan J. Rude   M   SBD       Raw   NaN   Junior
# 3114      Christopher J. Gard   M     B       Raw   NaN   Junior
# 9366       Mike Khamphavongsa   M     D       Raw  22.0   Junior
# 9369             Zachary John   M     D       Raw  22.0   Junior
# 14298            Colby Strunk   M     B       Raw  19.5   Junior
# 14397            Sean Simmons   M     B       Raw  20.0   Junior
# 14398          Charles Wilson   M     B       Raw  20.0   Junior
# 14399               Chad Thum   M     B       Raw  20.0   Junior
# 16281          Joshua McEllen   M     B       Raw  20.5   Junior
# 37075          Vitaliy Zhukov   M     B       Raw   NaN   Junior
# 37077             Ivan Zmiyov   M     B       Raw   NaN   Junior
# 37080        Vlad Shchetinkin   M     B       Raw   NaN   Junior
# 52568             Rob Patrick   M     B       Raw  20.0   Junior
# 69704           Andrew Mitton   M   SBD       Raw   NaN   Junior
# 69705             Jeff Turpin   M   SBD       Raw   NaN   Junior
# 69706       Kevin Khempukpong   M   SBD       Raw   NaN   Junior
# 69707             Sean Fraser   M   SBD       Raw   NaN   Junior
# 69708           Joseph Zinati   M   SBD       Raw   NaN   Junior
# 69713           Andrew Mitton   M     B       Raw   NaN   Junior
# 69738         Nicolas Gallant   M   SBD       Raw   NaN   Junior
# 69754               Zeb Hudon   M   SBD       Raw   NaN   Junior
# 69755          Patrick Durham   M   SBD       Raw   NaN   Junior
# 69756               Ben Downs   M   SBD       Raw   NaN   Junior
# ...                       ...  ..   ...       ...   ...      ...
# 821039         Jared Senffner   M   SBD       Raw   NaN   Junior
# 821042        Julian Zbotaniw   M   SBD       Raw   NaN   Junior
# 821044           Eric Mendoza   M   SBD       Raw   NaN   Junior
# 821045         Elliott Mondry   M   SBD       Raw  21.5   Junior
# 821061           Kevin Bedell   M   SBD       Raw  22.5   Junior
# 821323         Huba Hablicsek   M     D       Raw  20.0   Junior
# 821324          Štěpán Buchta   M     D       Raw  20.0   Junior
# 821325         Julian Scharpf   M     D       Raw  23.0   Junior
# 821326         Konrad Majocha   M     D       Raw  20.0   Junior
# 821327         Dávid Zámečník   M     D       Raw  22.0   Junior
# 821328         Antonín Tenkáč   M     D       Raw  21.0   Junior
# 821329  Helmut Silberbauer Jr   M     D       Raw  22.0   Junior
# 821330         Dominik Piecha   M     D       Raw  23.0   Junior
# 821331        Martin Havlíček   M     D       Raw  20.0   Junior
# 821332          Tibor Fülpesi   M     D       Raw  21.0   Junior
# 821333             Dávid Frey   M     D       Raw  22.0   Junior
# 821433      Dezső Péter Orbán   M     B       Raw  21.0   Junior
# 821434        Dominik Hudaček   M     B       Raw  23.0   Junior
# 821435         Dávid Zámečník   M     B       Raw  22.0   Junior
# 821436          Dušan Argaláš   M     B       Raw  22.0   Junior
# 821437         Július Mertvík   M     B       Raw  21.0   Junior
# 821438         Dominik Špinka   M     B       Raw  23.0   Junior
# 821439         Nikolas Neuman   M     B       Raw  21.0   Junior
# 821440         Antonín Tenkáč   M     B       Raw  21.0   Junior
# 821441             Adam Sobek   M     B       Raw  23.0   Junior
# 821442         Dominik Piecha   M     B       Raw  23.0   Junior
# 821443       Stanislav Močkor   M     B       Raw  22.0   Junior
# 821444          Martin Viktor   M     B       Raw  21.0   Junior
# 821445         Miroslav Kováč   M     B       Raw  21.0   Junior
# 821446            Maroš Gažúr   M     B       Raw  20.0   Junior
#
#         BodyweightKg WeightClassKg  Squat1Kg  Squat2Kg  \
# 2882            89.2            90       NaN       NaN
# 2886            99.1           100       NaN       NaN
# 2897            66.2          67.5       NaN       NaN
# 2904            80.4          82.5       NaN       NaN
# 2906            88.4            90       NaN       NaN
# 2923            82.4          82.5       NaN       NaN
# 3088            58.5            60      80.0      85.0
# 3093            77.9          82.5     137.5     147.5
# 3114            89.6            90       NaN       NaN
# 9366            59.0            60       NaN       NaN
# 9369           107.0           110       NaN       NaN
# 14298           81.6          82.5       NaN       NaN
# 14397           90.0            90       NaN       NaN
# 14398          110.0           110       NaN       NaN
# 14399          110.0           110       NaN       NaN
# 16281           74.3            75       NaN       NaN
# 37075           67.6            75       NaN       NaN
# 37077           64.4          67.5       NaN       NaN
# 37080           49.8            52       NaN       NaN
# 52568          112.4           125       NaN       NaN
# 69704           88.3            93       NaN       NaN
# 69705           80.0            83       NaN       NaN
# 69706           73.2            74       NaN       NaN
# 69707           93.4           105       NaN       NaN
# 69708          103.5           105       NaN       NaN
# 69713           88.3            93       NaN       NaN
# 69738           85.5            93       NaN       NaN
# 69754           89.8            93       NaN       NaN
# 69755           85.7            93       NaN       NaN
# 69756          125.0          120+       NaN       NaN
# ...              ...           ...       ...       ...
# 821039          66.5          67.5      87.5      92.5
# 821042          73.9            75     127.5    -135.0
# 821044          81.4          82.5     212.5     227.5
# 821045          78.9          82.5     185.0    -200.0
# 821061         121.8           125     182.5     192.5
# 821323          58.3            60       NaN       NaN
# 821324          66.1          67.5       NaN       NaN
# 821325          74.2            75       NaN       NaN
# 821326          81.4          82.5       NaN       NaN
# 821327          82.4          82.5       NaN       NaN
# 821328          93.2           100       NaN       NaN
# 821329          96.7           100       NaN       NaN
# 821330         104.8           110       NaN       NaN
# 821331         111.7           125       NaN       NaN
# 821332         121.7           125       NaN       NaN
# 821333         162.9          140+       NaN       NaN
# 821433          58.2            60       NaN       NaN
# 821434          79.7          82.5       NaN       NaN
# 821435          82.4          82.5       NaN       NaN
# 821436          80.9          82.5       NaN       NaN
# 821437          89.9            90       NaN       NaN
# 821438          88.1            90       NaN       NaN
# 821439          97.5           100       NaN       NaN
# 821440          93.2           100       NaN       NaN
# 821441          97.6           100       NaN       NaN
# 821442         104.8           110       NaN       NaN
# 821443         111.0           125       NaN       NaN
# 821444         129.1           140       NaN       NaN
# 821445         125.2           140       NaN       NaN
# 821446         131.4           140       NaN       NaN
#
#                          ...                    McCulloch  Tested  AgeClass  \
# 2882                     ...                        88.31      No     20-23
# 2886                     ...                        91.62      No     20-23
# 2897                     ...                       221.50      No     20-23
# 2904                     ...                       233.71      No     20-23
# 2906                     ...                       221.27      No     20-23
# 2923                     ...                       183.49      No     20-23
# 3088                     ...                       227.00     Yes       NaN
# 3093                     ...                       296.90     Yes       NaN
# 3114                     ...                          NaN     Yes       NaN
# 9366                     ...                       137.79      No     20-23
# 9369                     ...                       170.90      No     20-23
# 14298                    ...                       105.20      No       NaN
# 14397                    ...                        82.19     Yes     20-23
# 14398                    ...                        96.98     Yes       NaN
# 14399                    ...                       122.74      No     20-23
# 16281                    ...                       114.51      No     20-23
# 37075                    ...                        86.64      No       NaN
# 37077                    ...                        52.09      No       NaN
# 37080                    ...                        61.66      No       NaN
# 52568                    ...                        80.10      No     20-23
# 69704                    ...                       330.43     Yes       NaN
# 69705                    ...                       317.45     Yes       NaN
# 69706                    ...                       328.03     Yes       NaN
# 69707                    ...                       293.08     Yes       NaN
# 69708                    ...                       348.37     Yes       NaN
# 69713                    ...                        96.71     Yes       NaN
# 69738                    ...                       347.77     Yes       NaN
# 69754                    ...                       274.82     Yes       NaN
# 69755                    ...                       366.97     Yes       NaN
# 69756                    ...                       359.00     Yes       NaN
# ...                      ...                          ...     ...       ...
# 821039                   ...                       257.52      No       NaN
# 821042                   ...                       289.80      No       NaN
# 821044                   ...                       430.55      No       NaN
# 821045                   ...                       398.68      No     20-23
# 821061                   ...                       348.68      No     20-23
# 821323                   ...                       144.35      No     20-23
# 821324                   ...                       159.53      No     20-23
# 821325                   ...                       147.18      No     20-23
# 821326                   ...                       160.34      No     20-23
# 821327                   ...                       147.27      No     20-23
# 821328                   ...                       172.83      No     20-23
# 821329                   ...                       127.78      No     20-23
# 821330                   ...                       140.52      No     20-23
# 821331                   ...                       202.13      No     20-23
# 821332                   ...                       175.37      No     20-23
# 821333                   ...                       138.05      No     20-23
# 821433                   ...                        96.20      No     20-23
# 821434                   ...                       112.91      No     20-23
# 821435                   ...                        88.02      No     20-23
# 821436                   ...                        87.30      No     20-23
# 821437                   ...                       117.28      No       NaN
# 821438                   ...                       109.74      No     20-23
# 821439                   ...                       111.34      No     20-23
# 821440                   ...                       108.82      No     20-23
# 821441                   ...                       101.43      No     20-23
# 821442                   ...                        89.69      No     20-23
# 821443                   ...                       125.96      No     20-23
# 821444                   ...                       122.75      No     20-23
# 821445                   ...                       119.12      No     20-23
# 821446                   ...                        90.13      No     20-23
#
#          Country  Glossbrenner  Federation        Date  MeetCountry  \
# 2882       Chile         83.45      ACHIPO  2018-08-30        Chile
# 2886       Chile         88.08      ACHIPO  2018-08-30        Chile
# 2897       Chile        212.86      ACHIPO  2018-08-30        Chile
# 2904       Chile        223.50      ACHIPO  2018-08-30        Chile
# 2906        Peru        211.20      ACHIPO  2018-08-30        Chile
# 2923     Bolivia        175.40      ACHIPO  2018-08-30        Chile
# 3088         NaN        221.45       ADFPF  2011-04-30          USA
# 3093         NaN        286.96       ADFPF  2011-04-30          USA
# 3114         NaN           NaN       ADFPF  2011-04-30          USA
# 9366         NaN        133.03         APC  2018-06-23          USA
# 9369         NaN        162.26         APC  2018-06-23          USA
# 14298        NaN         97.68         APF  2012-07-28          USA
# 14397        NaN         76.90         WPC  2012-07-21          USA
# 14398        NaN         90.20         WPC  2012-07-21          USA
# 14399        USA        114.16         WPC  2012-07-21          USA
# 16281        NaN        107.56         APF  2014-04-27          USA
# 37075     Russia         84.03          BB  2011-12-10       Russia
# 37077        NaN         50.61          BB  2011-12-10       Russia
# 37080        NaN         60.77          BB  2011-12-10       Russia
# 52568        NaN         74.43        CAPO  2012-03-31    Australia
# 69704        NaN        318.56         CPU  2011-06-11       Canada
# 69705        NaN        306.66         CPU  2011-06-11       Canada
# 69706        NaN        317.48         CPU  2011-06-11       Canada
# 69707        NaN        282.19         CPU  2011-06-11       Canada
# 69708        NaN        334.45         CPU  2011-06-11       Canada
# 69713        NaN         93.24         CPU  2011-06-11       Canada
# 69738        NaN        335.50         CPU  2011-06-11       Canada
# 69754        NaN        264.85         CPU  2011-06-11       Canada
# 69755        NaN        354.01         CPU  2011-06-11       Canada
# 69756        NaN        341.95         CPU  2011-06-11       Canada
# ...          ...           ...         ...         ...          ...
# 821039       NaN        249.91        WUAP  2018-02-25          USA
# 821042       NaN        280.42        WUAP  2018-02-25          USA
# 821044       NaN        415.77        WUAP  2018-02-25          USA
# 821045       NaN        377.68        WUAP  2018-02-25          USA
# 821061       NaN        329.24        WUAP  2018-02-25          USA
# 821323   Hungary        136.74        WUAP  2018-10-15     Slovakia
# 821324   Czechia        150.34        WUAP  2018-10-15     Slovakia
# 821325   Austria        142.40        WUAP  2018-10-15     Slovakia
# 821326    Poland        150.33        WUAP  2018-10-15     Slovakia
# 821327  Slovakia        140.77        WUAP  2018-10-15     Slovakia
# 821328   Czechia        163.15        WUAP  2018-10-15     Slovakia
# 821329   Austria        121.71        WUAP  2018-10-15     Slovakia
# 821330    Poland        134.85        WUAP  2018-10-15     Slovakia
# 821331   Czechia        187.87        WUAP  2018-10-15     Slovakia
# 821332   Hungary        163.97        WUAP  2018-10-15     Slovakia
# 821333   Hungary        128.43        WUAP  2018-10-15     Slovakia
# 821433   Hungary         92.03        WUAP  2018-10-15     Slovakia
# 821434  Slovakia        109.08        WUAP  2018-10-15     Slovakia
# 821435  Slovakia         84.14        WUAP  2018-10-15     Slovakia
# 821436  Slovakia         83.48        WUAP  2018-10-15     Slovakia
# 821437  Slovakia        110.80        WUAP  2018-10-15     Slovakia
# 821438   Czechia        105.80        WUAP  2018-10-15     Slovakia
# 821439   Czechia        104.99        WUAP  2018-10-15     Slovakia
# 821440   Czechia        102.73        WUAP  2018-10-15     Slovakia
# 821441  Slovakia         97.55        WUAP  2018-10-15     Slovakia
# 821442    Poland         86.07        WUAP  2018-10-15     Slovakia
# 821443  Slovakia        119.42        WUAP  2018-10-15     Slovakia
# 821444   Hungary        114.45        WUAP  2018-10-15     Slovakia
# 821445  Slovakia        111.23        WUAP  2018-10-15     Slovakia
# 821446  Slovakia         83.14        WUAP  2018-10-15     Slovakia
#
#         MeetState                                MeetName
# 2882          NaN                 Campeonato Panamericano
# 2886          NaN                 Campeonato Panamericano
# 2897          NaN                 Campeonato Panamericano
# 2904          NaN                 Campeonato Panamericano
# 2906          NaN                 Campeonato Panamericano
# 2923          NaN                 Campeonato Panamericano
# 3088           IL       Macomb Record Breaker & Qualifier
# 3093           IL       Macomb Record Breaker & Qualifier
# 3114           IL       Macomb Record Breaker & Qualifier
# 9366           GA                  National Championships
# 9369           GA                  National Championships
# 14298          OR                    Primal Strength Fest
# 14397          MI         CanAm Bench Press Championships
# 14398          MI         CanAm Bench Press Championships
# 14399          MI         CanAm Bench Press Championships
# 16281          LA                       Amateur Nationals
# 37075         NaN                   National Championship
# 37077         NaN                   National Championship
# 37080         NaN                   National Championship
# 52568         TAS           Tasmanian State Championships
# 69704          NS                 Nova Scotia Provincials
# 69705          NS                 Nova Scotia Provincials
# 69706          NS                 Nova Scotia Provincials
# 69707          NS                 Nova Scotia Provincials
# 69708          NS                 Nova Scotia Provincials
# 69713          NS                 Nova Scotia Provincials
# 69738          QC                      Ste-Marie Festival
# 69754          MB                Portage Strength Classic
# 69755          MB                Portage Strength Classic
# 69756          MB                Portage Strength Classic
# ...           ...                                     ...
# 821039         IL  Winter Open Powerlifting Championships
# 821042         IL  Winter Open Powerlifting Championships
# 821044         IL  Winter Open Powerlifting Championships
# 821045         IL  Winter Open Powerlifting Championships
# 821061         IL  Winter Open Powerlifting Championships
# 821323        NaN                     World Championships
# 821324        NaN                     World Championships
# 821325        NaN                     World Championships
# 821326        NaN                     World Championships
# 821327        NaN                     World Championships
# 821328        NaN                     World Championships
# 821329        NaN                     World Championships
# 821330        NaN                     World Championships
# 821331        NaN                     World Championships
# 821332        NaN                     World Championships
# 821333        NaN                     World Championships
# 821433        NaN                     World Championships
# 821434        NaN                     World Championships
# 821435        NaN                     World Championships
# 821436        NaN                     World Championships
# 821437        NaN                     World Championships
# 821438        NaN                     World Championships
# 821439        NaN                     World Championships
# 821440        NaN                     World Championships
# 821441        NaN                     World Championships
# 821442        NaN                     World Championships
# 821443        NaN                     World Championships
# 821444        NaN                     World Championships
# 821445        NaN                     World Championships
# 821446        NaN                     World Championships
#
# [5116 rows x 36 columns]

# %%
plt.hist(inter['Best3SquatKg'][inter['Best3SquatKg']>0], bins=50)
plt.show()

# %%
inter82 = inter[inter['WeightClassKg']=='82.5']
inter100 = inter[inter['WeightClassKg']=='100']
inter110 = inter[inter['WeightClassKg']=='110']

# %%
fig, ax = plt.subplots(figsize=(6,4))

sns.distplot(inter82['Best3BenchKg'][inter82['Best3BenchKg']>0], bins=100, ax=ax, hist=False, label='83kg')
sns.distplot(inter100['Best3BenchKg'][inter100['Best3BenchKg']>0], bins=100, ax=ax, hist=False, label='100kg')
sns.distplot(inter110['Best3BenchKg'][inter110['Best3BenchKg']>0], bins=100, ax=ax, hist=False, label='110kg')

ax.set_xlabel('Bench Weight (Kg)')
ax.set_ylabel('Frequency')
ax.set_title('Bench Press Junior Distributions')

ax.axvline(111.36, label='Luke Polson', color='r')
ax.legend()
ax.grid()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(6,4))

sns.distplot(inter100['Best3BenchKg'][inter100['Best3BenchKg']>0], bins=25, ax=ax, label='100kg')

ax.set_xlabel('Bench Weight (Kg)')
ax.set_ylabel('Frequency')
ax.set_title('Bench Press 100kg Junior Distributions')

ax.legend()
ax.grid()
plt.show()
# Out:
# /Users/lukepolson/anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py:6499: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")
